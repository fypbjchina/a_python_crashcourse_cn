# %% [markdown]
# # Python Intro
#
# 1.1. 回顾，总结，答疑
#
# 1.2. 基础概念 - §02_变量
#
# 1.3. 人机对话 - print指令和进阶
#
# 1.4. 基础概念 - §03_列表

# %%
from IPython.display import Image
img1=Image(filename="WasMachtComputer_01.jpg")
img1

# %%
img2=Image(filename="StarWarsRoboter.jpg")
img2

# %%
img3= Image(filename="StarWarsRoboter.jpg")
img3

# %% [markdown]
# ## Variable
#
# var name
#
# C: int myno 21
# varname
#
# varNameIsMicrodigit  CamelCASE
# var_name_is_microdigit  Python
# Don't: __intit__
# Don't print print="myname"XXX

# %%
varname="data"

# %%
varname = 4
varname
# Out:
# 4

# %%
varname==4
# Out:
# True

# %%
4=varname
# Out:
#   Cell In[12], line 1
#     4=varname
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
var= "Name"
var
# Out:
# 'Name'

# %%
print((3+3)**0.5)
# Out:
# 2.449489742783178

# %%
print(3.14159)
# Out:
# 3.14159

# %%
print("[小疯子] Python 你爱我吗？")
print(True) # Python 永远对你忠心耿耿！！！
# Out:
# [小疯子] Python 你爱我吗？
# True

# %%
print(3+1 >=0)
# Out:
# True

# %% [markdown]
# ##  print __ fstring
#
# 模式： print(f"  {}")

# %%
pi = 3.1415926
print(f"圆周率的小数点两位：{pi:.2f}")
# Out:
# 圆周率的小数点两位：3.14

# %%
name = "晓疯子"
age = 28
print(f"欢迎{age}青春年少的{name}参加Python学习小组！")
# Out:
# 欢迎28青春年少的晓疯子参加Python学习小组！

# %%
from math import pi
print(f"[Microdigit] I can more: --) {pi:.100f}")
# Out:
# [Microdigit] I can more: --) 3.1415926535897931159979634685441851615905761718750000000000000000000000000000000000000000000000000000

# %%
x=5
y=16
print(f"x:{x:4}, y:{y:4}")
# Out:
# x:   5, y:  16

# %% [markdown]
# # list 列表
#
# 列表：大容器，什么都可以装！！！！
#
# utf-8
