# %% [markdown]
# # 插入图片

# %% [raw]
# 插入图片，默认居中：Markdown - ![text](image_path.png)

# %% [markdown]
# ![my photo](20231106_picture.png)

# %% [raw]
# 图片左对齐：Markdown - <img src="image_path.png" align="left"/>

# %% [markdown]
# <img src="20231106_picture.png" align="left"/>

# %% [raw]
# 图片右对齐：Markdown - <img src="image_path.png" align="right"/>

# %% [markdown]
# <img src="20231106_picture.png" align="right"/>

# %% [raw]
# 使用Code插入图片： Code - 路径用正斜杠，e.g. \\ or /
# from IPython.display import Image, display
# display(Image(filename='image_path.png', width=500, height=500))

# %%
from IPython.display import Image, display

display(Image(filename='A:/50_ADM/21_BCC/2023_Python_Beginner/04_Beginner/01_GitHub/fypbjchina2023/10_UserCase/20231106_picture.png', width=500, height=50))
